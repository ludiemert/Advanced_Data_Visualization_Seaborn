# %%
# import lib Seaborn

import seaborn as sns

# para garantir que os plots func corretamente dentro do Jupter
# %matplotlib inline

# %%
# como trab com os dados em plot da melhor forma posssivel, para visualizar os plots precisamos de dados
# vamos utilisar os dados da base de dados do Seaborn

tips = sns.load_dataset('tips') # usando os dados tips, variavel tips

# %%
tips # conjunto de dados de um restaurante
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# fazer uma analise desses dados com essa lib
# passar uma coluna que quer fazer um plot de distribuicao, passando uma coluna de DF

# analise de qto as pessoas gastam
sns.displot(tips['total_bill'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.displot(tips['total_bill'], kde=True)
# A curva que você quer é uma curva de densidade (KDE), não apenas histograma
# Por padrão, sns.displot() mostra histograma.
# Se quiser a curva suave de estatística, ative o kde=True:

plt.show()

# %%
# definir qtas subdivisoes eu quero no grafico
sns.displot(tips['total_bill'], kde=True, bins=300) # atualimente tem umas 10

# %%
# analisar duas variaveis ao mesmo tempo
# permite que crie duas variacoes e uma terceira com uma relacao entre elas

# analise com o DF no fim
sns.jointplot(x='total_bill', y='tip', data=tips)

# grafico de distribuicao conjunta
# grafico scater

# %%
# outro tipo de grafico, grafico de regrecao
# analisar duas variaveis ao mesmo tempo
# permite que crie duas variacoes e uma terceira com uma relacao entre elas
# grafico de distribuicao conjunta
# analise com o DF no fim

sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
# outro tipo de grafico, grafico de hexadecimal de analise

# analisar duas variaveis ao mesmo tempo
# permite que crie duas variacoes e uma terceira com uma relacao entre elas
# grafico de distribuicao conjunta
# analise com o DF no fim

sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')

# %%
# grafico que procura todas as variaveis numericas, variaveis numericas

sns.pairplot(tips) # visao geral dos dados

# %%
# separar os dados ex text e num, sex fem e sex masc

sns.pairplot(tips, hue='sex')

# %%
# usar paleta de cores, pegar cor quente e cor fria

sns.pairplot(tips, hue='sex', palette='coolwarm')

# %%
# grafico forma de ver concentracao de dados
sns.rugplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill'>

# %%
# mix de graficos
sns.kdeplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# add dois dados e dois graficos juntos
sns.kdeplot(tips["total_bill"])
sns.rugplot(tips["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Qual a distribuicao de homem e mulher nos dados?
# utilizar o seaborn e ver a resposta mais visual
# usar o barplot e ver um grafico de barras

sns.barplot(x="sex", y="total_bill", data=tips) # de onde ele vai encontrar esses dados => data=tips
# grafico pela media e separou por homens e mulheres
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# mostrar um desvio padrao viabilidade
import numpy as np

# %%
sns.barplot(x="sex", y="total_bill", data=tips, estimator=np.std) # mostrar um desvio padrao viabilidade
# de onde ele vai encontrar esses dados => data=tips
# funcao => para estimar valores => estimator=np.std
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# grafico de contagem
# mostrar qtos male and famele
sns.countplot(x="sex", data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# grafico boxplot

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# carregar dataset
# sns.boxplot(x="day", y="total_bill", data=tips, palette='rainbow')

sns.boxplot(x="day", y="total_bill", data=tips, hue="day", palette='rainbow', legend=False)

plt.show()
# grafico de distribuicao com percentil de dados, ele distrib onde os dados se distribuem
# a linha do meio eh a mediana nao a media
# mostra as pessoas que temos interesse em analisar
# ele mostra como as contas estao distrib por dia da semana

# %%
# outra forma de mostrar os dados via horizontal do boxplot
sns.boxplot(y="day", x="total_bill", data=tips, hue="day", palette='rainbow', )
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
# outra forma de mostrar os dados via horizontal do boxplot
sns.boxplot(y="day", x="total_bill", data=tips, hue="sex", palette='rainbow', legend=True, orient="h")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
# outra forma de mostrar os dados via horizontal do boxplot
sns.boxplot(x="day", y="total_bill", data=tips, hue="sex", palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# other grafic violinplot
sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", palette='rainbow') # o  hue="sex" faz ligacao entre homens e mulheres


# ve estimativa da carga de distribuicao
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# usando o method split condensa informacao e economiza espaco
sns.violinplot(x="day", y="total_bill", data=tips, hue="sex", palette='rainbow', split=True) # o  hue="sex" faz ligacao entre homens e mulheres
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# swarmplot => agrupa valores de maneira real
sns.swarmplot(x="day", y="total_bill", data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Plots de regressao
# mostrar lineares do nosso conjunto de dados das variaveis

# conjunto de dados de tips
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# comercar a correlacionar variaveis

sns.lmplot(x="total_bill", y="tip", data=tips)


# cria um grafico de regressao entre os dois valores

# %%
# comercar a correlacionar variaveis, fazer comparacao entre valores

sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex")


# cria um grafico de regressao entre os dois valores e comparacao

# %%
# outros atributos para customizar essas informacoes, com marcacao diferente (bolinha e triangulo)

sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex", markers=['o', 'v'])

# %%
# outros atributos para customizar essas informacoes, com marcacao diferente (x e triangulo)

sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex", markers=['x', 'v'])

# %%
# mudar o tamanho da informacao
# outros atributos para customizar essas informacoes, com marcacao diferente (bolinha e triangulo)

sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex", markers=['o', 'v'], scatter_kws={'s': 100})

# %%
# multiplas regressoes do time em varias regressoes

sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex", col="time")
# cria 2 graficos de almoco e jantar

# %%
# quebra em linhas em funcao do dia da semana
sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex", col="time", row="day")

# %%
# mudar as dimensoes dos nossos dados
sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex", markers=['o', 'v'], scatter_kws={'s': 100}, aspect=1.6)

# %%
# criar um grafico bem maior

sns.lmplot(x="total_bill", y="tip", data=tips, hue="sex", markers=['o', 'v'], scatter_kws={'s': 100}, aspect=1.6, height=8)

# %%
# Plots Matriciais

# %%
# trab outro conju de dados dentro do Seaborn chamado => flights

flights = sns.load_dataset("flights")

# %%
flights # voos realizados por varios anos, 144 linhas
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
# ver inf em 3 dimensoes
# transformar para matrix para refletir os dados no mapa de calor
# organizar a formatacao da tabela em idices e colunas

# shift + tab for open parametros pivot

flights.pivot_table(index="year", columns="month", values="passengers")  # dados reorganizados
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18120\64353260.py:7: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(index="year", columns="month", values="passengers")
# month    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# year
# 1949   112.0  118.0  132.0  129.0  121.0  135.0  148.0  148.0  136.0  119.0
# 1950   115.0  126.0  141.0  135.0  125.0  149.0  170.0  170.0  158.0  133.0
# 1951   145.0  150.0  178.0  163.0  172.0  178.0  199.0  199.0  184.0  162.0
# 1952   171.0  180.0  193.0  181.0  183.0  218.0  230.0  242.0  209.0  191.0
# 1953   196.0  196.0  236.0  235.0  229.0  243.0  264.0  272.0  237.0  211.0
# 1954   204.0  188.0  235.0  227.0  234.0  264.0  302.0  293.0  259.0  229.0
# 1955   242.0  233.0  267.0  269.0  270.0  315.0  364.0  347.0  312.0  274.0
# ...

# %%
# new DF 

df_flights_matrix = flights.pivot_table(index="year", columns="month", values="passengers", observed=False) 

# A função pivot_table tem um parâmetro chamado observed (usado quando você trabalha com categorias).
# Hoje, por padrão, ele é observed=False.
# Em versões futuras do Pandas, o padrão vai mudar para observed=True.

# %%
# MApa de calor

sns.heatmap(df_flights_matrix)
# Out:
# <Axes: xlabel='month', ylabel='year'>
